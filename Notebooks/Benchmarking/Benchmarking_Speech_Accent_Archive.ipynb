# %% [markdown]
# # Load Whisper

# %%
# !pip install -q --upgrade torch torchvision torchaudio
# !pip install -q git+https://github.com/huggingface/transformers
# !pip install -q accelerate optimum
# !pip install -q ipython-autotime

import torch
from transformers import pipeline

# Optional: load multiple versions of whisper
# models = ["openai/whisper-large","openai/whisper-large-v2","openai/whisper-large-v3"]
models = ["openai/whisper-large-v3"]

d_models = {}

for m in models:
  d_models[m] = pipeline("automatic-speech-recognition",
                m,
                torch_dtype=torch.float16,
                device="cuda:0")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 91.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 84.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 62.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.13 requires torch<2.2,>=1.10, but you have torch 2.2.0 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.2.0 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.2.0 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.5/402.5 kB 39.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 43.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.1 MB/s eta 0:00:00
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.94k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]

# %%
def transcribe(audio):
    outputs = {}

    r = d_models[models[-1]](audio,
                    chunk_length_s=30,
                    batch_size=24,
                    return_timestamps=True)['text']
    return r

# %% [markdown]
# # Speech Accent Archive [link](https://accent.gmu.edu/browse_language.php)

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.6.1

# %%
import pandas as pd
import pickle
from jiwer import wer, mer
from tqdm import tqdm

# %% [markdown]
# Extract file paths from SAA

# %%
saa_files = pd.read_html('https://accent.gmu.edu/soundtracks/')[0]
saa_files = list(saa_files['Name'])
saa_files = [x for x in saa_files if '.mp3' in str(x)]

# %% [markdown]
# Define stem of audio files

# %%
path_stem = 'https://accent.gmu.edu/soundtracks/'

# %% [markdown]
# Transcribe first audio file

# %%
transcribe(path_stem + saa_files[0])
# Out:
# ' Please call Stella, ask her to bring these things with her from the store. Six spoons of fresh snow peas, five thick slabs of blue cheese and maybe a snack for her brother Bob. We also need a small plastic snake and a big two-way frog for the kids. She can scoop these things into three red bags and we will go meet her Wednesday at the train station.'

# %% [markdown]
# Transcribe each file in the SAA

# %%
out = {}

for f in tqdm(saa_files):
  out[f] = transcribe(path_stem + f)

# %% [markdown]
# Save transcripts

# %%
with open('SAA_Whisperv3.pkl', 'wb') as f:
  pickle.dump(out, f)

# %% [markdown]
# ## Load for SAA

# %% [markdown]
# Load transcripts

# %%
with open('SAA_Whisperv3.pkl', 'rb') as f:
  saa_transcripts = pickle.load(f)

# %% [markdown]
# View example

# %%
saa_transcripts['english489.mp3']
# Out:
# ' Please call Stella. Ask her to bring these things with her from the store. Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob. We also need a small plastic snake and a big toy frog for the kids. She can school these things into three red bags and we will go meet her Wednesday at the train station.'

# %% [markdown]
# Define elicitation passage for WER/MER calculations

# %%
elicitation = 'Please call Stella.  Ask her to bring these things with her from the store:  Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob.  We also need a small plastic snake and a big toy frog for the kids.  She can scoop these things into three red bags, and we will go meet her Wednesday at the train station.'

# %% [markdown]
# Create a dataframe and add transcripts, WER, and MER

# %%
df = pd.DataFrame()
df.index = saa_transcripts.keys()
df['whisper'] = saa_transcripts.values()
df['wer'] = [wer(elicitation, x) for x in saa_transcripts.values()]
df['mer'] = [mer(elicitation, x) for x in saa_transcripts.values()]
df
# Out:
#                                                           whisper       wer  \
# afrikaans1.mp3   Please call Stella, ask her to bring these th...  0.072464
# afrikaans2.mp3   Please call Stella. Ask her to bring these th...  0.043478
# afrikaans3.mp3   Please call Stella. Ask her to bring these th...  0.043478
# afrikaans4.mp3   Please call Stella. Ask her to bring these th...  0.028986
# afrikaans5.mp3   Please call Stella. Ask her to bring these th...  0.057971
# ...                                                           ...       ...
# yoruba8.mp3      Please call Stella. Ask her to bring these th...  0.115942
# yupik1.mp3       Please call Stella. Ask her to bring these th...  0.028986
# yupik2.mp3       Please call Stella. Ask her to bring these th...  0.217391
# yupik3.mp3       Please call Stella. Ask her to bring these th...  0.028986
# zulu1.mp3        Please call Stella. Ask her to bring these th...  0.057971
#
#                      mer
# afrikaans1.mp3  0.072464
# afrikaans2.mp3  0.043478
# afrikaans3.mp3  0.043478
# afrikaans4.mp3  0.028986
# afrikaans5.mp3  0.057143
# ...                  ...
# yoruba8.mp3     0.115942
# yupik1.mp3      0.028986
# yupik2.mp3      0.182927
# yupik3.mp3      0.028986
# zulu1.mp3       0.057971
#
# [3011 rows x 3 columns]

# %% [markdown]
# #SAA Metadata

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import trange

# %%
outs = {}

for i in trange(1,3036):
  url = f'https://accent.gmu.edu/browse_language.php?function=detail&speakerid={i}'
  r = requests.get(url)

  html = BeautifulSoup(r.content)
  t = [x.text for x in html.find_all('li') if '</em>' in str(x)]
  t = {x.split(':')[0]:x.split(':')[1][1:] for x in t}
  t['features'] = [x.text for x in html.findAll('a') if 'browse_language.php?function=detail&amp' in str(x)][1:]

  t['index'] = i
  n = html.findAll('h5')[1].em.text
  outs[n] = t
# Out:
# 100%|██████████| 3035/3035 [46:19<00:00,  1.09it/s]

# %%
with open('/content/drive/Shareddrives/Ling Thesis/Data_Dir/SAA_metadata.pkl', 'wb') as f:
  pickle.dump(outs, f)

# %%
df['to_join'] = [x[0] for x in df.index.str.split('.')]

# %%
df_meta = pd.DataFrame(outs).T

# %%
df_meta['to_join'] = df_meta.index

# %%
df_merged = df.merge(df_meta, on='to_join', how='left')

# %%
df_merged.index = df_merged['to_join']
df_merged.fillna(' , ', inplace=True)
df_merged['birth place'] = df_merged['birth place'].apply(lambda x: str(x).replace(' (map)',''))
df_merged['native language'] = df_merged['native language'].apply(lambda x: str(x).split('\n')[0])
df_merged['length of english residence'] = df_merged['length of english residence'].apply(lambda x: str(x).split(' ')[0])

df_merged['age'] = df_merged['age, sex'].apply(lambda x: str(x).split(', ')[0])
df_merged['sex'] = df_merged['age, sex'].apply(lambda x: str(x).split(', ')[1])

# %%
df_merged = df_merged.drop(['whisper','age, sex', 'to_join'], axis=1)
df_merged.to_csv('SAA_full.csv')

# %%
df_merged
# Out:
#                  wer       mer                        birth place  \
# to_join
# afrikaans1  0.072464  0.072464             virginia, south africa
# afrikaans2  0.043478  0.043478             pretoria, south africa
# afrikaans3  0.043478  0.043478  pretoria, transvaal, south africa
# afrikaans4  0.028986  0.028986             pretoria, south africa
# afrikaans5  0.057971  0.057143            cape town, south africa
# ...              ...       ...                                ...
# yoruba8     0.115942  0.115942               ibadan, oyo, nigeria
# yupik1      0.028986  0.028986                bethel, alaska, usa
# yupik2      0.217391  0.182927                  nome, alaska, usa
# yupik3      0.028986  0.028986                  nome, alaska, usa
# zulu1       0.057971  0.057971                 bulawayo, zimbabwe
#
#            native language        other language(s) age of english onset  \
# to_join
# afrikaans1       afrikaans                  tswana                     9
# afrikaans2       afrikaans     dutch german french                     5
# afrikaans3       afrikaans  gujarati sindhi french                     4
# afrikaans4       afrikaans           flemish dutch                     8
# afrikaans5       afrikaans                     none                    6
# ...                    ...                      ...                  ...
# yoruba8             yoruba                     none                    2
# yupik1               yupik                 spanish                     1
# yupik2               yupik                 russian                     6
# yupik3               yupik                     none                    6
# zulu1                 zulu           shona ndebele                    14
#
#            english learning method english residence  \
# to_join
# afrikaans1                academic               usa
# afrikaans2                academic               usa
# afrikaans3            naturalistic               usa
# afrikaans4                academic               usa
# afrikaans5                academic         australia
# ...                            ...               ...
# yoruba8                   academic      nigeria, usa
# yupik1                naturalistic            alaska
# yupik2                    academic               usa
# yupik3                naturalistic               usa
# zulu1                     academic               usa
#
#            length of english residence  \
# to_join
# afrikaans1                         0.5
# afrikaans2                          10
# afrikaans3                        20.7
# afrikaans4                          15
# afrikaans5                           9
# ...                                ...
# yoruba8                             21
# yupik1                              31
# yupik2                              40
# yupik3                              42
# zulu1                                7
#
#                                                      features index age  \
# to_join
# afrikaans1  [final obstruent devoicing, interdental fricat...     1  27
# afrikaans2      [final obstruent devoicing, vowel shortening]     2  40
# afrikaans3  [final obstruent devoicing, r to trill, non as...   418  43
# afrikaans4                                                 []  1159  26
# afrikaans5                                                 []  1432  19
# ...                                                       ...   ...  ..
# yoruba8                                                    []  2985  21
# yupik1      [final obstruent devoicing, interdental fricat...   571  31
# yupik2                                                     []  2637  40
# yupik3                                                     []  2638  42
# zulu1       [final obstruent devoicing, interdental fricat...   406  24
#
#                 sex
# to_join
# afrikaans1  female
# afrikaans2    male
# afrikaans3    male
# afrikaans4    male
# afrikaans5    male
# ...             ...
# yoruba8       male
# yupik1      female
# yupik2        male
# yupik3      female
# zulu1       female
#
# [3011 rows x 13 columns]
